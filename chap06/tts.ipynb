# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

response = client.audio.speech.create(
    model='tts-1-hd',
    voice='alloy',
    input="Hello world! this is a TTS test"
)

response.write_to_file("hello_world.mp3")

import IPython.display as ipd

ipd.Audio("hello_world.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import json

with open("./image_quiz_eng.json", 'r', encoding="utf-8") as f:
    eng_dict = json.load(f)
eng_dict
# Out:
# [{'no': 1,
#   'eng': "Which of the following descriptions of the image is incorrect?\n\n- (1). There is only one sea turtle in the image.\n- (2). The sea turtle is swimming in clear water.\n- (3). There are several other marine creatures around.\n- (4). The sea turtle's shell is brown.",
#   'img': 'matthew-mosbauer-roEHxjIr-Js-unsplash.jpg'},
#  {'no': 2,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n\n- (1). You can see a person holding a steering wheel.\n- (2). A desert landscape is visible outside the car window.\n- (3). There are tall buildings in the background.\n- (4). The driver is wearing a cap.',
#   'img': 'nir-himi-g521j0feHE0-unsplash.jpg'},
#  {'no': 3,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1). There are sand dunes adjacent to the sea.\n- (2). There are people walking in line on top of the sand dunes.\n- (3). The sky is clear and blue.\n- (4). Waves are crashing onto the shore.',
#   'img': 'nir-himi-gSIjbABf9sc-unsplash.jpg'}]

# %%
voices = ['alloy', 'ash', 'coral', 'echo', 'fable', 'onyx', 'nova', 'sage', 'shimmer']

for q in eng_dict:
    no = q['no']
    quiz = q['eng']
    quiz = quiz.replace("- (1)", "- One.\t")
    quiz = quiz.replace("- (2)", "- Two.\t")
    quiz = quiz.replace("- (3)", "- Three.\t")
    quiz = quiz.replace("- (4)", "- Four.\t")

    print(no, quiz)

    voice = voices[no % len(voices)]

    response = client.audio.speech.create(
        model = 'tts-1-hd',
        voice = voice,
        input=f'#{no}. {quiz}'
    )

    response.write_to_file(f"./{no}.mp3")
# Out:
# 1 Which of the following descriptions of the image is incorrect?
#
# - One.	. There is only one sea turtle in the image.
# - Two.	. The sea turtle is swimming in clear water.
# - Three.	. There are several other marine creatures around.
# - Four.	. The sea turtle's shell is brown.
# 2 Which of the following descriptions of the image is incorrect?
#
# - One.	. You can see a person holding a steering wheel.
# - Two.	. A desert landscape is visible outside the car window.
# - Three.	. There are tall buildings in the background.
# - Four.	. The driver is wearing a cap.
# 3 Which of the following descriptions of the image is incorrect?
# - One.	. There are sand dunes adjacent to the sea.
# - Two.	. There are people walking in line on top of the sand dunes.
# - Three.	. The sky is clear and blue.
# - Four.	. Waves are crashing onto the shore.
